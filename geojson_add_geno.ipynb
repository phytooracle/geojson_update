# %%
import pandas as pd
import geopandas as gpd

# %%
df = pd.read_csv('/home/emmanuelgonzalez/Gantry_fieldbook_2020_Revised_Irr_TRT.csv', dtype='str').set_index('Plot')

# %%
df
# Out:
#       Field          Species Experiment Revised_irrigation_treatment Range  \
# Plot
# 0101  south  Sorghum bicolor    EMS_pop                           WW    01
# 0102  south  Sorghum bicolor    EMS_pop                           WW    01
# 0103  south  Sorghum bicolor    EMS_pop                           WW    01
# 0104  south  Sorghum bicolor    EMS_pop                           WW    01
# 0105  south  Sorghum bicolor    EMS_pop                           WW    01
# ...     ...              ...        ...                          ...   ...
# 5428  south  Sorghum bicolor    EMS_pop                           WL    54
# 5429  south  Sorghum bicolor    EMS_pop                           WL    54
# 5430  south  Sorghum bicolor    EMS_pop                           WL    54
# 5431  south  Sorghum bicolor    EMS_pop                           WL    54
# 5432  south  Sorghum bicolor    EMS_pop                           WL    54
#
# ...

# %%
gj = gpd.read_file('/home/emmanuelgonzalez/season11_multi_latlon.geojson')

# %%
gj['genotype'] = None

for i, row in gj.iterrows():
    #row['genotype'] = None
    plot = row['ID']
    row_df = df.loc[plot]
    geno = row_df['PI_accession']
    #print(plot, geno)
    gj['genotype'][i] = str(geno)
# Out:
# <ipython-input-113-de71bf04b98f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gj['genotype'][i] = str(geno)

# %%
gj.to_file('/home/emmanuelgonzalez/season11_multi_latlon_geno.geojson', driver='GeoJSON')
